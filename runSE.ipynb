# %%
run run_cold+hot_f475w_Nie_20210103.py
# Out:
# Running cold
# Running hot
# Read cold and hot catalogs
# ['NUMBER', 'FLUX_ISO', 'FLUXERR_ISO', 'MAG_ISO', 'MAGERR_ISO', 'FLUX_AUTO', 'FLUXERR_AUTO', 'MAG_AUTO', 'MAGERR_AUTO', 'MAG_BEST', 'MAGERR_BEST', 'KRON_RADIUS', 'BACKGROUND', 'X_IMAGE', 'Y_IMAGE', 'ALPHA_J2000', 'DELTA_J2000', 'CXX_IMAGE', 'CYY_IMAGE', 'CXY_IMAGE', 'ELLIPTICITY', 'FWHM_IMAGE', 'FLUX_RADIUS', 'FLAGS', 'CLASS_STAR', 'A_IMAGE', 'B_IMAGE', 'XMIN_IMAGE', 'YMIN_IMAGE', 'XMAX_IMAGE', 'YMAX_IMAGE', 'ELONGATION', 'THETA_IMAGE', 'ISOAREA_IMAGE']
# Including hot detections
# ('N:', 8, 0, 1599)
# ('N:', 8, 1, 1598)
# ('N:', 8, 2, 1596)
# ('N:', 8, 3, 1596)
# ('N:', 8, 4, 1587)
# ('N:', 8, 5, 1587)
# ('N:', 8, 6, 1586)
# ('N:', 8, 7, 1583)
# 1583
# Creating combined segmentation map
# (1583, 0)
# (1583, 1)
# (1583, 2)
# (1583, 3)
# (1583, 4)
# (1583, 5)
# (1583, 6)
# (1583, 7)
# (1583, 8)
# (1583, 9)
# (1583, 10)
# (1583, 11)
# (1583, 12)
# (1583, 13)
# (1583, 14)
# (1583, 15)
# (1583, 16)
# (1583, 17)
# (1583, 18)
# ...

# %%
 if len(idx_c) > 1 and len(cold_table['KRON_RADIUS'][idx_c]) > 0:
            cold_table['KRON_RADIUS'][idx_c] = np.median(cold_table['KRON_RADIUS'])

# %%
cold_table
# Out:
# array((1., 13.15563, 2.566713, 23.2522, 0.2119, 104.1275, 7.228564, 21.0061, 0.0754, 21.0061, 0.0754, 8.82, 0.09747316, 1099.4043, 326.8728, 11.2180455, 41.6562863, 0.96399647, 0.6317324, -0.20099126, 0.22, 6.79, 2.977, 0., 0.759, 1.287, 1.004, 1098., 325., 1101., 329., 1.282, 74.41, 17.),
# ...

# %%
len(table_allll)
# Out:
# 1622

# %%
import numpy as np

# Set up matplotlib
import matplotlib.pyplot as plt
import os
from astropy.io import fits

# %%
data_path, res_path = './data/', './res_test/'
# Out:
# 0

# %%
os.system('cd '+data_path+'; astcrop --section=10:4157,40:2148 --mode=img --hdu=1 hlsp_phat_hst_acs-wfc_12057-m31-b09-f01_f475w_v1_drz.fits')
# Out:
# 0

# %%
hdu_list = fits.open('./data/ds9b09f01f475chip1.fits')
hdu_list.info()
# Out:
# Filename: ./data/ds9b09f01f475chip1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      69   (4148, 2109)   float32

# %%
2109-58.75
# Out:
# 2050.25

# %%
hdu_list = fits.open('./data/ds9b09f01f475w7.fits')
hdu_list.info()
# Out:
# Filename: ./data/ds9b09f01f475w7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      25   (1295, 470)   float32

# %%
hdu_list = fits.open('./data/dsB09F01-3.0_drz.fits')
hdu_list.info()
# Out:
# Filename: ./data/dsB09F01-3.0_drz.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      25   (1295, 470)   float32

# %%
print(hdu_list[0].data)
# Out:
# [[0.24386056 0.24386056 0.24386056 ... 0.12969033 0.12969033 0.12969033]
#  [0.24386056 0.24386056 0.24386056 ... 0.12969033 0.12969033 0.12969033]
#  [0.24386056 0.24386056 0.24386056 ... 0.12969033 0.12969033 0.12969033]
#  ...
#  [0.10237297 0.10237297 0.10237297 ... 0.18251471 0.18251471 0.18251471]
#  [0.10237297 0.10237297 0.10237297 ... 0.18251471 0.18251471 0.18251471]
#  [0.09868278 0.09868278 0.09868278 ... 0.11969352 0.11969352 0.11969352]]

# %%
hdu_list = fits.open('./data/hlsp_phat_hst_acs-wfc_12057-m31-b09-f01_f475w_v1_drz.fits')
hdu_list.info()
# Out:
# Filename: ./data/hlsp_phat_hst_acs-wfc_12057-m31-b09-f01_f475w_v1_drz.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     489   ()
#   1  SCI           1 ImageHDU       143   (4217, 4243)   float32
#   2  WHT           1 ImageHDU       150   (4217, 4243)   float32
#   3  CTX           1 ImageHDU       150   (4217, 4243)   int32

# %%
import os
res_path = './res_test/'
pref = 'hlsp_phat_hst_acs-wfc_12057-m31-b09-f01_f475w_v1_'
outcat = res_path+pref+'hot.cat'

# %%
reg1 = res_path + 'test_f475w3.0.reg'
reg2 = res_path + 'test_f475w4.0.reg'
os.system("awk '{print \"ellipse(\"$14\",\"$15\",\"($26*$12)\",\"($27*$12)\",\"$33\")\"}' "+outcat+ " > " + reg1)
os.system("awk '{print $16,$17}' "+outcat+ " > " + reg2)
# Out:
# 0

# %%
os.system('cd '+data_path+'; ds9 -zoom to fit ds9b09f01f475chip1.fits -saveimage ds9b09f01f475w5.fits -exit')
# Out:
# 0

# %%
os.system('cd '+data_path+'; ds9 -width 1360 -height 768  hlsp_phat_hst_acs-wfc_12057-m31-b09-f01_f475w_v1_drz.fits -zoom 4 -pan 161.875 58.75 image -saveimage ds9b09f01f475w7.fits -exit')
# Out:
# 0

# %%
323.75*2+161.875
# Out:
# 809.375

# %%
58.75+117.5*2
# Out:
# 293.75

# %%
x = np.arange(58.75,293.75,117.5)

# %%
print('x[1]')
# Out:
# x[1]

# %%
help(np.linspace)
# Out:
# Help on function linspace in module numpy.core.function_base:
#
# linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None)
#     Return evenly spaced numbers over a specified interval.
#
#     Returns `num` evenly spaced samples, calculated over the
#     interval [`start`, `stop`].
#
#     The endpoint of the interval can optionally be excluded.
#
#     Parameters
#     ----------
#     start : scalar
#         The starting value of the sequence.
#     stop : scalar
#         The end value of the sequence, unless `endpoint` is set to False.
#         In that case, the sequence consists of all but the last of ``num + 1``
#         evenly spaced samples, so that `stop` is excluded.  Note that the step
#         size changes when `endpoint` is False.
#     num : int, optional
#         Number of samples to generate. Default is 50. Must be non-negative.
#     endpoint : bool, optional
#         If True, `stop` is the last sample. Otherwise, it is not included.
# ...

# %%
data_path, res_path = './data/', './res_test/'  
X = np.arange(161.875,809.375,323.75)
Y = np.arange(58.75,293.75,117.5)
N = 0
table_alll = []
outcat = res_path+'ds9b09f01f475w_comb.cat'
for p in range(len(Y)):
    for q in range(len(X)):
        x = X[q]
        y = Y[p]
        n = str(N)
        os.system('cd '+data_path+'; ds9 -width 1360 -height 768 ds9b09f01f475chip1.fits -zoom 4 -pan to %f %f image -saveimage ds9b09f01f475w%s.fits -exit' %(x,y,n))
        N = N+1

# %%
os.system('cd '+data_path+'; ds9 -width 1360 -height 768 hlsp_phat_hst_acs-wfc_12057-m31-b09-f01_f475w_v1_drz.fits -zoom 4 -pan to '60 + 'image'+' -saveimage ds9b09f01f475w'+'1'+'.fits -exit')
# Out:
#   File "<ipython-input-103-35f54b6257e2>", line 1
#     os.system('cd '+data_path+'; ds9 -width 1360 -height 768 hlsp_phat_hst_acs-wfc_12057-m31-b09-f01_f475w_v1_drz.fits -zoom 4 -pan to' 60  ' ' 60 + 'image'+' -saveimage ds9b09f01f475w'+'1'+'.fits -exit')
#                                                                                                                                          ^
# SyntaxError: invalid syntax

# %%
b = [0,1,2,3]
print(range(1,len(b)))
# Out:
# [1, 2, 3]

# %%
run run_cold+hot_f475w_Nie_20201022.py
# Out:
# Running cold
# Running hot
# Read cold and hot catalogs
# ['NUMBER', 'FLUX_ISO', 'FLUXERR_ISO', 'MAG_ISO', 'MAGERR_ISO', 'FLUX_AUTO', 'FLUXERR_AUTO', 'MAG_AUTO', 'MAGERR_AUTO', 'MAG_BEST', 'MAGERR_BEST', 'KRON_RADIUS', 'BACKGROUND', 'X_IMAGE', 'Y_IMAGE', 'ALPHA_J2000', 'DELTA_J2000', 'CXX_IMAGE', 'CYY_IMAGE', 'CXY_IMAGE', 'ELLIPTICITY', 'FWHM_IMAGE', 'FLUX_RADIUS', 'FLAGS', 'CLASS_STAR', 'A_IMAGE', 'B_IMAGE', 'XMIN_IMAGE', 'YMIN_IMAGE', 'XMAX_IMAGE', 'YMAX_IMAGE', 'ELONGATION', 'THETA_IMAGE', 'ISOAREA_IMAGE']
# Including hot detections
# ('N:', 99, 0, 2602)
# ('N:', 99, 1, 2600)
# ('N:', 99, 2, 2599)
# ('N:', 99, 3, 2598)
# ('N:', 99, 4, 2597)
# ('N:', 99, 5, 2595)
# ('N:', 99, 6, 2594)
# ('N:', 99, 7, 2593)
# ('N:', 99, 8, 2589)
# ('N:', 99, 9, 2588)
# ('N:', 99, 10, 2587)
# ('N:', 99, 11, 2584)
# ('N:', 99, 12, 2583)
# ('N:', 99, 13, 2582)
# ('N:', 99, 14, 2577)
# ('N:', 99, 15, 2576)
# ('N:', 99, 16, 2575)
# ('N:', 99, 17, 2574)
# ('N:', 99, 18, 2572)
# ('N:', 99, 19, 2571)
# ...
